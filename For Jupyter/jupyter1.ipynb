# %%
print("hello world")
# Out:
# hello world

# %%
print(1)
# Out:
# 1

# %%
print("1")
# Out:
# 1

# %%
import pandas

# %%
df = pandas.read_csv("D:\MSCS\Python\Programs\proj_email\expired_Nov_Dec.csv")
df
# Out:
#      Member ID                         Category     First Name     Last Name  \
# 0      3027816               Individual Monthly        Malathi  Chandramouli
# 1      3027817            Family Monthly Member  Malika Connie       Ancheta
# 2      3027820               Individual Monthly         Sanjay          Bari
# 3      3027839               Individual Monthly           Irma         Manzo
# 4      3027853       Senior Monthly Full Access        William          Huff
# 5      3027859       Senior Monthly Full Access         Walter      Williams
# 6      3027918               Individual Monthly       Srikumar        Poigai
# 7      3027930          TT Individual (Monthly)     Jong Boong           Lee
# 8      3027941               Individual Monthly       Ramkajal      Upadhyay
# 9      3027945       TT Family (Monthly) Member         Steven      Meredith
# 10     3027947        Fitness Senior  (Monthly)       Devinder       Dosanjh
# ...
